# %% [markdown]
# # 2.1 Variables y tipos basicos
#
# Notebook de practicas para alumnado de 3o de Biotecnologia.
#
# ## Objetivos
#
# - Entender que una variable debe recibir un valor antes de usarse.
# - Entender la idea de constante y la convencion usada en Python.
# - Nombrar variables con criterios adecuados.
# - Trabajar con `int`, `float`, `bool`, `complex` y `str`.
# - Usar operadores aritmeticos, relacionales y de asignacion.
# - Conocer ASCII, Unicode, cadenas, escapes e interpolacion.
# - Usar `print()`, `input()`, `type()` y comentarios de forma fluida.
#
# ## Instrucciones
#
# - La notebook esta organizada de menor a mayor dificultad.
# - Cada ejercicio tiene su propia celda de codigo.
# - Ejecuta primero los ejemplos y despues resuelve los ejercicios.

# %% [markdown]
# ## 1. Variables, asignacion y constantes

# %% [markdown]
# Una variable es un nombre que referencia un valor. En Python no se puede usar una variable antes de asignarle un valor.
#
# Python no tiene constantes estrictas, pero por convenio se escriben en mayusculas.

# %%
# Ejemplo 1: asignacion sencilla
gen = "TP53"
print(gen)
# Out:
# TP53
# La secuencia es larga

# %%
# Ejemplo 2: reasignacion
lecturas = 120
print(lecturas)
lecturas = 145
print(lecturas)

# %%
# Ejemplo 3: constante por convencion
PI = 3.14159
MAX_MUESTRAS = 96
print(PI)
print(MAX_MUESTRAS)

# %% [markdown]
# ### Nombres de variables
#
# - `snake_case`: estilo mas usado en Python.
# - `camelCase`: aparece en algunos proyectos.
# - `PascalCase`: suele reservarse para clases.
#
# Ejemplos:
#
# - `longitud_gen`
# - `longitudGen`
# - `LongitudGen`

# %% [markdown]
# ### Ejercicio 1
# Crea una variable llamada `nombre_gen` y guardale el valor `"BRCA1"`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 2
# Crea una variable `num_muestras` con el valor entero `24` y muestrala por pantalla.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 3
# Crea una variable `temperatura_incubacion` con el valor `37.0`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 4
# Crea una variable `muestra_valida` con el valor booleano adecuado para indicar que la muestra es valida.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 5
# Crea una constante por convencion llamada `NUMERO_CROMOSOMAS_HUMANO` con el valor `46`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 6
# Crea tres variables equivalentes para almacenar el nombre de una proteina, usando `snake_case`, `camelCase` y `PascalCase`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 7
# Asigna a `lecturas_fastq` el valor `1000`, imprimelo, cambialo a `1250` e imprimelo de nuevo.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 8
# Escribe un comentario que explique para que sirve una variable `ph_medio`, luego declarala con valor `7.4`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 2. Tipos basicos de Python

# %% [markdown]
# Los tipos basicos que vamos a trabajar en esta practica son:
#
# - `int`
# - `float`
# - `bool`
# - `complex`
# - `str`

# %%
# Ejemplo 4: tipos basicos
num_genes = 20345
contenido_gc = 0.417
muestra_control = False
senal = 3 + 4j
secuencia = "ATGCGT"

print(type(num_genes))
print(type(contenido_gc))
print(type(muestra_control))
print(type(senal))
print(type(secuencia))

# %%
# Ejemplo 5: bool tambien es un tipo numerico especial
print(True)
print(False)
print(True + 2)
print(False + 2)

# %%
# Ejemplo 6: numeros complejos
z1 = 2 + 3j
z2 = complex(5, -1)
print(z1)
print(z2)
print(type(z1))

# %% [markdown]
# ### Ejercicio 9
# Declara una variable `num_celulas` de tipo entero con valor `1500000`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 10
# Declara una variable `masa_molecular` de tipo float con valor `18.015`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 11
# Declara una variable `resultado_positivo` de tipo bool con valor verdadero.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 12
# Declara una variable `impedancia` de tipo complex con valor `5 + 2j`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 13
# Declara una variable `especie` de tipo string con valor `"Arabidopsis thaliana"`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 14
# Usa `type()` para mostrar el tipo de `num_celulas`, `masa_molecular`, `resultado_positivo`, `impedancia` y `especie`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 15
# Crea cinco variables, una de cada tipo basico, con nombres relacionados con un experimento de expresion genica.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 16
# Comprueba si `True` y `False` son del tipo `bool` usando `type()`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 17
# Crea dos variables complejas distintas, imprimelas y muestra tambien su tipo.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 18
# Crea una variable `temperatura_texto = "37.5"` y otra `temperatura_numero` convirtiendo ese valor a `float`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 3. Operadores aritmeticos

# %% [markdown]
# Operadores principales:
#
# - suma: `+`
# - resta: `-`
# - multiplicacion: `*`
# - division: `/`
# - potencia: `**`
# - division entera: `//`
# - modulo: `%`

# %%
# Ejemplo 7: operaciones basicas
a = 10
b = 3
print(a + b)
print(a - b)
print(a * b)
print(a / b)
print(a ** b)
print(a // b)
print(a % b)

# %%
# Ejemplo 8: precedencia y parentesis
resultado1 = 2 + 3 * 4
resultado2 = (2 + 3) * 4
print(resultado1)
print(resultado2)

# %% [markdown]
# ### Ejercicio 19
# Calcula la suma de `125` y `75` y guarda el resultado en `total_lecturas`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 20
# Resta `12` a `50` y guarda el resultado en `muestras_restantes`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 21
# Multiplica `35` por `4` para calcular el numero total de pocillos usados.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 22
# Divide `250` entre `8` y guarda el resultado en `media_por_muestra`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 23
# Calcula `2` elevado a `10` y guarda el resultado en `num_combinaciones`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 24
# Calcula la division entera de `103` entre `10`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 25
# Calcula el resto de dividir `103` entre `10`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 26
# Calcula la expresion `5 + 2 * 3` y despues `(5 + 2) * 3`. Compara los resultados.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 27
# Si una secuencia tiene `450` nucleotidos y otra `325`, calcula la longitud total y la diferencia entre ambas.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 28
# En una placa de 96 pocillos se han usado 67. Calcula cuantos quedan libres usando una operacion aritmetica.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 29
# Calcula el contenido GC si tienes `120` bases G o C dentro de una secuencia de `300` nucleotidos.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 4. Operadores relacionales y logicos

# %% [markdown]
# Operadores relacionales principales:
#
# - igual que: `==`
# - distinto de: `!=`
# - mayor que: `>`
# - menor que: `<`
# - mayor o igual que: `>=`
# - menor o igual que: `<=`

# %%
# Ejemplo 9: comparaciones
expresion_a = 12.4
expresion_b = 10.1
print(expresion_a > expresion_b)
print(expresion_a == expresion_b)
print(expresion_a != expresion_b)

# %%
# Ejemplo 10: combinando comparaciones con bool
temperatura = 37
print(temperatura >= 35)
print(temperatura <= 40)

# %% [markdown]
# ### Ejercicio 30
# Comprueba si `15` es igual a `15`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 31
# Comprueba si `8` es distinto de `10`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 32
# Comprueba si `42` es mayor que `30`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 33
# Comprueba si `0.25` es menor que `0.5`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 34
# Comprueba si `37` es mayor o igual que `37`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 35
# Comprueba si `12` es menor o igual que `9`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 36
# Guarda en una variable booleana si la longitud de una secuencia de `500` nucleotidos es mayor que `300`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 37
# Compara dos variables `ph_1 = 7.2` y `ph_2 = 7.2` e indica si son iguales.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 5. Operadores de asignacion

# %% [markdown]
# Ademas de `=`, Python permite operadores compuestos como `+=`, `-=`, `*=`, `/=`, `//=`, `%=`, `**=`.

# %%
# Ejemplo 11: asignacion compuesta
lecturas = 100
lecturas += 25
lecturas *= 2
lecturas -= 10
print(lecturas)

# %%
# Ejemplo 12: mas variantes
x = 17
x //= 3
print(x)
x **= 2
print(x)

# %% [markdown]
# ### Ejercicio 38
# Crea una variable `contador = 0` y sumale `1` usando `+=`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 39
# Crea `volumen = 100.0` y restale `12.5` usando `-=`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 40
# Crea `copias = 3` y multiplicalas por `4` usando `*=`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 41
# Crea `masa = 80` y dividela entre `5` usando `/=`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 42
# Crea `fragmentos = 23` y aplica `//=` con `4`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 43
# Crea `resto = 23` y aplica `%=` con `4`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 44
# Crea `potencia = 3` y elevala al cuadrado usando `**=`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 6. Cadenas de texto: declaracion, ASCII, Unicode y escapes

# %% [markdown]
# En Python las cadenas pueden declararse con comillas simples, comillas dobles o triples comillas.
#
# ASCII representa un conjunto basico de caracteres. Unicode extiende ese conjunto para incluir muchisimos alfabetos, simbolos y caracteres especiales. En Python 3 las cadenas son Unicode, lo que facilita trabajar con nombres cientificos, acentos o simbolos.
#
# Escapes principales:
#
# - `\n`: salto de linea
# - `\t`: tabulador
# - `\r`: retorno de carro

# %%
# Ejemplo 13: distintas formas de declarar cadenas
cadena1 = 'ADN'
cadena2 = "ARN"
cadena3 = '''Proteina\nmultilinea'''
print(cadena1)
print(cadena2)
print(cadena3)

# %%
# Ejemplo 14: caracteres Unicode
nombre = "José"
especie = "Caenorhabditis elegans"
simbolo = "β-globina"
print(nombre)
print(especie)
print(simbolo)

# %%
# Ejemplo 15: escapes
print("Gen\tExpresion")
print("BRCA1\t12.4")
print("Linea 1\nLinea 2")
print("ABC\rXYZ")
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: '/usr/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Ejercicio 45
# Declara una cadena usando comillas simples con el texto `ADN`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 46
# Declara una cadena usando comillas dobles con el texto `ARN mensajero`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 47
# Declara una cadena multilínea con triples comillas que describa brevemente una muestra biologica.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 48
# Crea una cadena con un nombre propio que lleve tilde y muestrala.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 49
# Crea una cadena con un simbolo Unicode cientifico, por ejemplo `μ`, `β` o `α`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 50
# Escribe dos `print()` que muestren una tabla sencilla usando `\t` entre columnas.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 51
# Usa `\n` para mostrar tres lineas consecutivas con tres nombres de genes.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 52
# Prueba `\r` en una cadena corta y observa el resultado.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 53
# Escribe una cadena que incluya comillas dobles dentro del texto sin producir error.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 54
# Escribe una cadena que incluya comillas simples dentro del texto sin producir error.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 7. Interpolacion y composicion de cadenas

# %% [markdown]
# Formas frecuentes de interpolar valores en cadenas:
#
# - concatenacion con `+`
# - separando argumentos en `print()`
# - estilo antiguo con `%`
# - metodo `.format()`
# - f-strings

# %%
# Ejemplo 16: concatenacion
gen = "MYC"
mensaje = "El gen analizado es " + gen
print(mensaje)

# %%
# Ejemplo 17: print con varios argumentos
gen = "EGFR"
expresion = 8.45
print("Gen:", gen, "Expresion:", expresion)

# %%
# Ejemplo 18: interpolacion con %
gen = "PTEN"
valor = 5.2
print("El gen %s tiene expresion %.1f" % (gen, valor))
# Out:
# El gen PTEN tiene expresion 5.2

# %%
# Ejemplo 19: metodo format
gen = "KRAS"
mutacion = "G12D"
print("El gen {} presenta la mutacion {}".format(gen, mutacion))
print("La mutacion {m} pertenece al gen {g}".format(g=gen, m=mutacion))
# Out:
# El gen KRAS presenta la mutacion G12D
# La mutacion G12D pertenece al gen KRAS

# %%
# Ejemplo 20: f-strings
gen = "BRAF"
frecuencia = 0.2378
print(f"El gen {gen} presenta una frecuencia de {frecuencia:.2%}")
# Out:
# El gen BRAF presenta una frecuencia de 23.78%

# %% [markdown]
# ### Ejercicio 55
# Concatena dos cadenas para formar el mensaje `"Gen analizado: TP53"`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 56
# Usa `print()` con varios argumentos para mostrar el nombre de una especie y su numero de cromosomas.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 57
# Usa interpolacion con `%` para mostrar un gen y una expresion con dos decimales.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 58
# Usa `.format()` con argumentos posicionales para mostrar una secuencia y su longitud.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 59
# Usa `.format()` con argumentos nombrados para mostrar una proteina y su organismo.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 60
# Usa una f-string para mostrar un porcentaje de GC con tres decimales.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 61
# Usa una f-string para mostrar el nombre de una muestra, el numero de lecturas y un comentario final en una sola frase.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 8. `print()`, `input()`, `type()` y comentarios

# %% [markdown]
# `print()` muestra informacion por pantalla. `input()` lee texto desde teclado. Recuerda que `input()` devuelve siempre una cadena, por lo que a menudo hay que convertir el resultado con `int()` o `float()`.
#
# Los comentarios empiezan por `#` y sirven para explicar el codigo.

# %%
# Ejemplo 21: print y type
valor = 42
print(valor)
print(type(valor))

# %%
# Ejemplo 22: input sin conversion
# Descomenta para probarlo en una sesion interactiva.
#nombre_muestra = input("Introduce el nombre de la muestra: ")
#print(nombre_muestra)
#print(type(nombre_muestra))
# Out:
# holaasds
# <class 'str'>

# %%
# Ejemplo 23: input con conversion
# Descomenta para probarlo en una sesion interactiva.
# num_lecturas = int(input("Introduce el numero de lecturas: "))
# print(num_lecturas)
# print(type(num_lecturas))

# %% [markdown]
# ### Ejercicio 62
# Usa `print()` para mostrar el mensaje `Inicio del analisis`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 63
# Crea una variable `profundidad = 300` y muestra su tipo con `type()`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 64
# Escribe dos comentarios: uno al principio explicando el bloque y otro junto a una asignacion de variable.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 65
# Escribe un ejemplo con `input()` para pedir el nombre de una muestra y mostrarlo despues. Puedes dejar las lineas comentadas si no quieres ejecutarlo ahora.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 66
# Escribe un ejemplo con `input()` para pedir una edad de cultivo en horas y convertirla a entero.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 67
# Escribe un ejemplo con `input()` para pedir un valor decimal de pH y convertirlo a `float`.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## 9. Retos integrados de bioinformatica

# %% [markdown]
# En estos ejercicios debes combinar varios conceptos a la vez.

# %% [markdown]
# ### Ejercicio 68
# Crea variables para una secuencia de ADN, su longitud y el porcentaje GC. Muestra todo con una f-string.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 69
# Crea una variable `lecturas = "2500"`, conviertela a entero, sumale `500` con `+=` y muestra el resultado.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 70
# Declara `gen = "BRCA2"` y `longitud = 3418`. Muestra una frase con concatenacion, otra con `.format()` y otra con f-string.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 71
# Comprueba si una secuencia de longitud `1200` supera el umbral `1000` y guarda el resultado en una variable booleana.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 72
# Crea una constante `TEMPERATURA_PCR = 95`, una variable `ciclos = 30` y muestra un mensaje explicativo.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 73
# Escribe una salida tabulada con `print()` que muestre tres genes y un valor numerico de expresion para cada uno.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 74
# Crea una cadena multilinea con informacion de una muestra: identificador, especie y tejido.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 75
# Define tres variables numericas y construye una expresion aritmetica que combine suma, multiplicacion, division y potencia.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 76
# Usa `input()` para pedir el nombre de un gen y su longitud. Convierte la longitud a entero y muestra una frase final. Si no quieres ejecutarlo ahora, dejalo comentado.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 77
# Crea un ejemplo breve donde aparezcan `int`, `float`, `bool`, `complex` y `str`, y muestra el tipo de cada uno.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ### Ejercicio 78
# Escribe un mini informe por pantalla sobre una muestra biologica usando al menos un comentario, una constante, una comparacion, una operacion aritmetica y una f-string.

# %%
# Escribe aqui tu solucion

# %% [markdown]
# ## Cierre
#
# Si has llegado hasta aqui, ya has practicado los conceptos fundamentales de variables y tipos basicos en Python, junto con el uso de cadenas, operadores, comentarios, `print()`, `input()` y `type()`.
#
# Sugerencia para trabajo en casa: repite los ejercicios usando otros nombres de variables, otros datos biologicos y otras formas de interpolacion para ganar fluidez sintactica.
